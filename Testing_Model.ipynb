# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanshah2288/Diabetes-Predictor/blob/main/Testing_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Model Predictor

# %%
from Diabetes_Prediction import Diabetes_Prediction

# %% [markdown]
# ## Predict Your New input Value....

# %%
Diabetes_Prediction()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# ✅ Yes, the patient **has** diabetes!
# 1
